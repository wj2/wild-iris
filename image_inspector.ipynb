# %%
from importlib import reload

import wi_code.image_display as img_disp
import wi_code.read_format as rf

import matplotlib.pyplot as plt

# %%
# %matplotlib inline

plt.plot([0], [1])

# %%
reload(rf)

rf.make_html('.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-d73e93adb1a4> in <module>
#       1 reload(rf)
#       2
# ----> 3 rf.make_html('.')
#
# ~/Dropbox/personal/wild-iris/wi_code/read_format.py in make_html(folder, use_toc, use_gloss, use_post_toc, toc_template, toc_main, toc_sub, toc_html_templ, toc_fname, gloss_line_templ, gloss_fname, gloss_mkd_templ, gloss_html_templ, nav_bar_templ, end_nav_bar_templ, beg_nav_bar_templ, **kwargs)
#     246               beg_nav_bar_templ=beg_nav_bar_template,
#     247               **kwargs):
# --> 248     page_dict = read_files(folder, **kwargs)
#     249
#     250     ref_dict = {}
#
# ~/Dropbox/personal/wild-iris/wi_code/read_format.py in read_files(folder, file_template, picture_folder, use_gloss)
#     198             flower_col = pickle.load(col_file)
#     199
# ...

# %%
reload(img_disp)
reload(rf)

img_disp.resave_images('.')
# rf.make_html('.')
# Out:
# 2400 2329.4117647058824
# 1800 1800.0
# 1.2941176470588236 0.7727272727272727
# 2272 2205.1764705882356
# 1704 1704.0000000000002
# 1.2941176470588236 0.7727272727272727
# 2560 2200.0000000000005
# 1700 1700.0000000000002
# 1.2941176470588236 0.7727272727272727
# 1600 1376.9411764705885
# 1064 1064.0000000000002
# 1.2941176470588236 0.7727272727272727
# 1280 1105.1764705882354
# 854 854.0
# 1.2941176470588236 0.7727272727272727
# 1280 1242.3529411764707
# 960 960.0000000000001
# 1.2941176470588236 0.7727272727272727
# 4280 4270.588235294118
# 3300 3300.0
# 1.2941176470588236 0.7727272727272727
# 1280 1242.3529411764707
# 960 960.0000000000001
# 1.2941176470588236 0.7727272727272727
# 4048 3928.9411764705883
# 3036 3036.0
# 1.2941176470588236 0.7727272727272727
# 2132 2069.294117647059
# 1599 1599.0
# 1.2941176470588236 0.7727272727272727
# 1280 1241.058823529412
# 959 959.0000000000001
# 1.2941176470588236 0.7727272727272727
# 2816 2733.176470588235
# 2112 2112.0
# ...

# %%
reload(img_disp)
reload(rf)

imgs = list(img_disp.get_images('.'))

# %%
720/931
# Out:
# 0.7733619763694952

# %%
reload(img_disp)
img_ind = 17

img_disp.plot_img(imgs[img_ind][1], imgs[img_ind][0])
# Out:
# 2592 2515.764705882353
# 3888 3888.0000000000005
# 0.6470588235294118 1.5454545454545454
# (<Figure size 1152x576 with 2 Axes>, None)

# %%
reload(img_disp)

img_disp.resave_images('.')
# Out:
# 2400 2329.4117647058824
# 1800 1800.0
# 2272 2205.1764705882356
# 1704 1704.0000000000002
# 2560 2200.0000000000005
# 1700 1700.0000000000002
# 2848 2764.2352941176473
# 4272 4272.0
# 1280 1105.1764705882354
# 854 854.0
# 1280 1242.3529411764707
# 960 960.0000000000001
# 4280 4270.588235294118
# 3300 3300.0
# 1280 1242.3529411764707
# 960 960.0000000000001
# 1500 1294.1176470588236
# 2000 2000.0000000000002
# 2132 2069.294117647059
# 1599 1599.0
# 1280 1241.058823529412
# 959 959.0000000000001
# 4000 3450.764705882353
# 5333 5333.0
# 2592 2505.4117647058824
# 3872 3872.0
# 1180 931.764705882353
# 720 720.0000000000001
# 869 711.7647058823529
# 550 550.0
# 2000 1718.5882352941176
# 1328 1328.0
# 1200 1164.7058823529412
# 900 900.0
# 2592 2515.764705882353
# 3888 3888.0000000000005
# 1500 1474.6470588235295
# 2279 2279.0
# 1023 993.8823529411765
# 768 768.0
# 2304 2171.529411764706
# 1678 1678.0
# 1500 1294.1176470588236
# 2000 2000.0000000000002
# 1000 860.5882352941177
# 665 665.0
# ...
